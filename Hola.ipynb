# %%
# %matplotlib notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as anim

# %% [markdown]
# $$ \vec{r} (t) = Acos(\omega t)\hat{i} +   Asin (\omega t)\hat{j} $$

# %%
A=1
omega=2*np.pi/10
N=int(1e2)

# %%
t=np.linspace(0,10,N)
r=np.zeros((N,2))

# %%
def GetPosition():
    r[:,0] =A*np.cos(omega*t)
    r[:,1] =A*np.sin(omega*t)

# %%
GetPosition()

# %%
r
# Out:
# array([[ 1.00000000e+00,  0.00000000e+00],
#        [ 9.97986676e-01,  6.34239197e-02],
#        [ 9.91954813e-01,  1.26592454e-01],
#        [ 9.81928697e-01,  1.89251244e-01],
#        [ 9.67948701e-01,  2.51147987e-01],
#        [ 9.50071118e-01,  3.12033446e-01],
#        [ 9.28367933e-01,  3.71662456e-01],
#        [ 9.02926538e-01,  4.29794912e-01],
#        [ 8.73849377e-01,  4.86196736e-01],
#        [ 8.41253533e-01,  5.40640817e-01],
#        [ 8.05270258e-01,  5.92907929e-01],
#        [ 7.66044443e-01,  6.42787610e-01],
#        [ 7.23734038e-01,  6.90079011e-01],
#        [ 6.78509412e-01,  7.34591709e-01],
#        [ 6.30552667e-01,  7.76146464e-01],
#        [ 5.80056910e-01,  8.14575952e-01],
#        [ 5.27225468e-01,  8.49725430e-01],
#        [ 4.72271075e-01,  8.81453363e-01],
#        [ 4.15415013e-01,  9.09631995e-01],
#        [ 3.56886222e-01,  9.34147860e-01],
#        [ 2.96920375e-01,  9.54902241e-01],
#        [ 2.35758936e-01,  9.71811568e-01],
# ...

# %%
#plt.scatter(r[:,0],r[:,1],color="black",s=0.5)
#plt.axis("equal")

# %%
fig = plt.figure( figsize=(4,2))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

def init():
    
    ax2.set_ylim(-A,A)
    ax1.set_ylim(-A,A)

def Update(i):
    
    plot = ax1.clear()
    plot = ax2.clear()
    
    init()
    
    plot = ax1.plot(t[:i],r[:i,0],color="b")
    plot = ax2.plot(t[:i],r[:i,1],color="k")
    return plot

Anim = anim.FuncAnimation(fig, Update, frames=N, init_func=init )
# Out:
# <img src="data:image/png;base64,..." width="400">

# %%
v=np.zeros((N,2))

# %%
def GetVelocity():
    v[:,0]=-A*omega*np.sin(omega*t)
    v[:,1]=A*omega*np.cos(omega*t)

# %%
GetVelocity()

# %%
v
# Out:
# array([[-0.00000000e+00,  6.28318531e-01],
#        [-3.94823632e-04,  6.28318407e-01],
#        [-7.89647109e-04,  6.28318035e-01],
#        ...,
#        [ 7.89647109e-04,  6.28318035e-01],
#        [ 3.94823632e-04,  6.28318407e-01],
#        [ 1.53893655e-16,  6.28318531e-01]])

# %%
plt.plot(v[:,0],v[:,1])

# %%
Writer = anim.writers["ffmpeg"]
writer_ =Writer(fps=10,metadata=dict(artist="M"))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# C:\Users\MA7291~1.GAR\AppData\Local\Temp/ipykernel_7444/39995519.py in <module>
# ----> 1 Writer = anim.writers["ffmpeg"]
#       2 writer_ =Writer(fps=10,metadata=dict(artist="M"))
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\animation.py in __getitem__(self, name)
#     149         if self.is_available(name):
#     150             return self._registered[name]
# --> 151         raise RuntimeError(f"Requested MovieWriter ({name}) not available")
#     152
#     153
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available

# %%
Anim
